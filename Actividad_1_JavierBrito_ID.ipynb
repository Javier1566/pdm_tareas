# %% [markdown]
# <h1><center>
#
# </center></h1>
# <font size="6"><center>
# EIE 401
# PROCESAMIENTO DIGITAL MULTIMEDIA
# </center></font>

# %% [markdown]
# <center><h2>Actividad 1</h2></center>
# <center><h3>Fundamentos</h3></center>
# <center><h3>Profesor: Jorge Cardenas</h3></center>
#
# <center><h3>Por: Javier Brito Parra</h3></center>
# <center><h5>Pontificia Universidad Catolica de Valparaiso</h5></center>

# %% [markdown]
# ## 1. Crea tu perfil y un repositorio para las actividades del curso en Github
# <p align="justify">
# Tanto en el mercado laboral como a nivel de investigación científica, se ha normalizado el uso de herramientas de desarrollo continuo (CI/CD), entre las que se cuenta a GitHub.
#
# <p align="justify">
# Debes crear tu cuenta y primer repositorio en GitHub.
#
# El respositorio deberá tener un archivo README y subcarpetas para las actividades del semestre. Allí deberás alojar el archivo de Jupyter Notebook con el código y todos los recursos para la posterior revisión de tu trabajo.
#
# Este medio será el canal de entrega de tus actividades cada semana, de tal forma que al final del curso debes tener un portafolio de tu trabajo para presentar a tus colegas o en la industria.

# %%
# Javier1566
# https://github.com/Javier1566/pdm_tareas

# %% [markdown]
# ## 2. Define en python vectores y funciones
# <p align="justify">
# Debes generar vectores que representan intervalos de tiempo o de una variable.
# Debes ingresar las funciones matemáticas y evaluarlas en los vectores generados.
#
# $$
# f(x) =  e^{-x^2}
# $$
#
# $$
# f(z) =  ysin(x)
# $$
#
# <p align="justify">
# Haz una gráfica para cada uno de las funciones evaluadas.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Se definen las funciones matematicas:

# %%
def funcion1(x):## Funcion f(x) exponencial
    return np.exp(-1*(x**2))
    
def funcion2(x,y):## Funcion f(z) bidimensional
    return y*np.sin(x)

# %%
x = np.linspace(-5,5,100)
y = funcion1(x) ## Se utiliza la variable 'y' para el primer grafico

# %% [markdown]
# ### 2.1 Comandos para graficar f(x):

# %%
plt.figure(figsize=(11,3))
plt.title("Grafico de f(x):")
plt.plot(x,y)
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.show()

# %% [markdown]
# * Se redefine 'y' para graficar la funcion f(z).

# %%
y = np.linspace(-5,5,100)# Vector de valores entre -5 y 5 con 100 muestras
X, Y = np.meshgrid(x, y)## Convertir los vectores x e y en arreglos bidimensionales
Z = funcion2(X,Y)

# %% [markdown]
# ### 2.2 Comandos para graficar f(z):

# %%
figure = plt.figure()

ax = figure.add_subplot(111, projection = '3d')
ax.set_title("Funcion f(z):")
ax.plot_surface(X, Y, Z, cmap = 'Blues')
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.show()

# %% [markdown]
# ## 3. Ruido
# <p align="justify">
# Crear una señal (senoidal, cosenoidal, etc) y demuestra la agregación de ruido.

# %% [markdown]
# ### 3.1 Ruido Gaussiano
# Debes agregar la señal de ruido a la que creaste previamente. Adicionalmente, debes mostrar una gráfica con el resultado.

# %% [markdown]
# ### 3.1 Desarrollo de la actividad:

# %%
def funcion_cos (x):
    return np.cos(x)
def funcion_sin (x):
    return np.sin(x)
    
def funcion3(x):
    return 0.6*np.cos(x-1.5)**2+1*np.sin(x-1.5)+0.2*np.cos((x-1.5)*2)

# %% [markdown]
# * Se definen las funciones para posteriormente graficarlas.

# %%
xvector = np.linspace(0,15,1000)
f_cos = funcion_cos(xvector)
f_sin = funcion_sin(xvector)
f_funcion3 = funcion3(xvector)

# %% [markdown]
# ### 3.1 Grafico de señales generadas :

# %%
## comandos para graficar la funcion coseno
plt.figure(figsize=(11,3))
plt.subplot(1, 3, 1)
plt.plot(xvector, f_cos, color='red')
plt.title('Señal Coseno')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Cosenoidal')

## comandos para graficar la funcion seno
plt.subplot(1, 3, 2)
plt.plot(xvector, f_sin, color = 'blue')
plt.title('Señal Seno')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Senoidal')

## comandos para generar la funcion creada para la actividad 
plt.subplot(1, 3, 3)
plt.title("Señal periodica antes del ruido")
plt.plot(xvector,f_funcion3)
plt.xlabel("Eje x")
plt.ylabel("Funcion generada")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.1 Grafico de ruido gaussiano :

# %%
ruido_gaussiano=np.random.normal(0,1,1000) ##Se define el vector de ruido con
# media = 0 // desviacion estndar = 1 // numero de datos = 10000
## Comandos grafico de ruido gaussiano
plt.figure(figsize=(8,3))
plt.plot(xvector,ruido_gaussiano)
plt.title('Señal Ruido Gaussiano')
plt.xlabel('Eje de x')
plt.ylabel('V(x)')
plt.show()

# %% [markdown]
# * Se generan los ruidos a las señales generadas, se trabajara con 30% y 50% de ruido respectivamente.

# %%
# Señal contaminada al 30%
cos_ruido_30 = 0.3*ruido_gaussiano + f_cos
sin_ruido_30 = 0.3*ruido_gaussiano + f_sin
funcion3_ruido_30 = 0.3*ruido_gaussiano + f_funcion3

# Señal contaminada al 50%
cos_ruido_50 = 0.5*ruido_gaussiano + f_cos
sin_ruido_50 = 0.5*ruido_gaussiano + f_sin
funcion3_ruido_50 = 0.5*ruido_gaussiano + f_funcion3

# %% [markdown]
# ### 3.1 Grafico de señales contaminadas con 30% de ruido :

# %%
## comandos para graficar la funcion coseno
plt.figure(figsize=(11,3))
plt.subplot(1, 3, 1)
plt.plot(xvector, cos_ruido_30, color='red')
plt.title('Señal Coseno con 30% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Cosenoidal')

## comandos para graficar la funcion seno
plt.subplot(1, 3, 2)
plt.plot(xvector, sin_ruido_30, color = 'blue')
plt.title('Señal Seno con 30% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Senoidal')

## comandos para graficar la funcion generada
plt.subplot(1, 3, 3)
plt.plot(xvector, funcion3_ruido_30, color = 'green')
plt.title('Señal periodica generada con 30% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion generada')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.1 Grafico de señales contaminadas con 30% de ruido :

# %%
## comandos para graficar la funcion coseno
plt.figure(figsize=(11,3))
plt.subplot(1, 3, 1)
plt.plot(xvector, cos_ruido_50, color='red')
plt.title('Señal Coseno con 50% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Cosenoidal')

## comandos para graficar la funcion seno
plt.subplot(1, 3, 2)
plt.plot(xvector, sin_ruido_50, color = 'blue')
plt.title('Señal Seno con 50% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion Senoidal')

## comandos para graficar la funcion generada
plt.subplot(1, 3, 3)
plt.plot(xvector, funcion3_ruido_50, color = 'green')
plt.title('Señal periodica generada con 50% de ruido')
plt.xlabel('Eje de x')
plt.ylabel('Funcion generada')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Ruido Rosa
# Investiga en que consiste el ruido rosa, cual es la diferencia del ruido gaussiano y demuéstralo.

# %% [markdown]
# * El término de 'ruido rosa' y ruido blanco obtienen sus nombres por donde estan ubicados en el dominio de las frecuencias, se les asocian colores dependiendo de la frecuencia de dicho ruido, existiendo asi ruido azul, violeta, etc.
# * Su densidad espectral es inversamente proporcional a su frecuencia.
# * En el contexto de procesamiento de audio puede utilizarse para enmascarar

# %% [markdown]
# * Se utilizo el codigo mostrado en las referencias para representar la diferencia entre los ruidos.
# * Solamente se modifico el tamaño y los titulos de los graficos y resultados.

# %%
def noise_psd(N, psd = lambda f: 1):
    X_white = np.fft.rfft(np.random.randn(N))
    S = psd(np.fft.rfftfreq(N))
    S = S / np.sqrt(np.mean(S**2))
    X_shaped = X_white * S
    return np.fft.irfft(X_shaped)

def PSDGenerator(f):
    return lambda N: noise_psd(N, f)
@PSDGenerator ##Ruido blanco
def white_noise(f):
    return 1

@PSDGenerator ##Ruido rosa
def pink_noise(f):
    return 1/np.where(f == 0, float('inf'), np.sqrt(f))

plt.style.use('dark_background')
plt.figure(figsize=(11, 3), tight_layout=True)

# Graficar ruido blanco
frequencies = np.fft.rfftfreq(30*50_000)
spectrum_white = np.abs(np.fft.rfft(white_noise(30*50_000)))
plt.loglog(frequencies, spectrum_white, color='white', label='Ruido Blanco')

# Graficar ruido rosa
spectrum_pink = np.abs(np.fft.rfft(pink_noise(30*50_000)))
plt.loglog(frequencies, spectrum_pink, color='hotpink', label='Ruido Rosa')

plt.title("Representacion de ruidos en el dominio de la frecuencia")
plt.legend()

plt.show()

# %% [markdown]
# ## 4. Referencias
# <p align="justify">
#
# [Generate colors of noise in Python] https://stackoverflow.com/questions/67085963/generate-colors-of-noise-in-python
#
# [Generación de señales]https://medium.com/@martinkarlsson.io/fourier-transform-in-python-f15b3243ce9a
#
# [Fourier Transform]https://pythonnumericalmethods.berkeley.edu/notebooks/chapter24.04-FFT-in-Python.html
#
# [SciPy] https://docs.scipy.org/doc/scipy/tutorial/fft.html
#
# [Fourier con numpy] https://towardsdatascience.com/fourier-transform-the-practical-python-implementation-acdd32f1b96a
